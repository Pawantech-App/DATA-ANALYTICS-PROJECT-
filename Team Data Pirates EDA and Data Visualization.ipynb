# %% [markdown]
# DATA ANALYTICS PROJECT BY TEAM DATA PIRATES

# %% [markdown]
# DATASET SELECTION:
# 1.Dataset name: Camera Dataset
# 2.Source: Kaggle
# 3.No. of Observations: 1038
# 4.No. of Columns: 13
# 5.Percentage of Missing Values: 5%

# %% [markdown]
# EXPLORATORY DATA ANALYSIS:
#
# Describe the features of the dataset
#
# 1.MODEL: This feature of the dataset describes about the various models of the different type(company) of cameras present in the choosen dataset.
#
# 2.RELEASE DATE: This feature of the dataset describes about the various release dates(in years)of the different models of the cameras in the dataset.
#
# 3.MAX RESOLUTION: This feature of the dataset describes about the maximum resolution of the different models of the cameras present in the dataset.
#
# 4.MIN RESOLUTION: This feature of the dataset describes about the minimum resolution of the different models of the cameras present in the dataset.
#
# 5.EFFECTIVE PIXELS: This feature of the dataset describes about the different number of effective pixels of each camera model in the dataset.
#
# 6.ZOOM WIDE: This feature of the dataset describes about the short focal length of the different cameras in the dataset.
#
# 7.ZOOM TELE: This feature of the dataset describes about the long focal length of the different cameras in the dataset.
#
# 8.NORMAL FOCUS RANGE: This feature of the dataset describes about the lens of the various cameras in the dataset with a focal length approximately equal to the diagonal of the film format or of a digital camera's image sensor. Most 35mm cameras normal lenses have a focal length of approximately 50 mm.
#
# 9.MACRO FOCUS RANGE: This feature of the dataset describes about the focal length of the various cameras in the dataset, a macro lens (50 mm on a 35 mm camera) can focus so close that lighting remains difficult. Macro lens has a focal lengths from about 100 to 200 mm.
#
# 10.STORAGE INCLUDED: This feature of the dataset describes about the inbuilt storage that is included in the various cameras of the dataset.
#
# 11.WEIGHT: This feature of the dataset describes about the weight of the cameras(inclusive of the weight of the batteries)in the dataset.
#
# 12.DIMENSION: This feature of the dataset describes about the dimensions of the cameras in the dataset.
#
# 13.PRICE: This feature of the dataset describes about the prices of the cameras in the dataset.

# %%
# %config IPCompleter.greedy=True
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('E:\PES COLLEGE\SEM 5\Data Analytics Project\camera_dataset.csv')

# %%
df
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             NaN
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %% [markdown]
# EDA and Data Visualization:

# %% [markdown]
# No of rows and columns in the dataset (shape):

# %%
df.shape
# Out:
# (1038, 13)

# %% [markdown]
# Number of missing values in the dataset attribute-wise:

# %%
df.isnull().sum()
# Out:
# Model                        0
# Release date                 0
# Max resolution               1
# Low resolution              54
# Effective pixels            35
# Zoom wide (W)               85
# Zoom tele (T)               85
# Normal focus range         137
# Macro focus range          128
# Storage included           125
# Weight (inc. batteries)     23
# Dimensions                  16
# Price                        0
# dtype: int64

# %% [markdown]
# Total number of missing values in the dataset:

# %%
df.isnull().sum().sum()
# Out:
# 689

# %% [markdown]
# Total percentage of missing values in the dataset:

# %%
(df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# 5.105973025048169

# %% [markdown]
# Handling of missing values in the dataset(Incomplete Data):
# We have used the mean(average) of each column to replace the NaN values of that column.

# %%
for i in df:
       if(i=="Model"):
            continue;
       if(i=='Price' or i=='Weight (inc. batteries)'):
           df[i].fillna(df[i].mean(),inplace=True)
       else:
           df[i].fillna(int(df[i].mean()),inplace=True)

# %%
df
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0          1871.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          0
# Storage included           0
# Weight (inc. batteries)    0
# Dimensions                 0
# Price                      0
# dtype: int64

# %% [markdown]
# There are no duplicate values/rows in the dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Outliers:

# %% [markdown]
# Visualisation of Outliers in the dataset:

# %%
df.boxplot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Finding the No. of outliers in each of the columns/features in the Dataset:

# %%
outliers=dict()
for i in df.columns:
    if i!='Model':
        Q1=df[i].quantile(q=0.25,interpolation='midpoint')
        Q3=df[i].quantile(q=0.75,interpolation='midpoint')
        IQR=Q3-Q1
        for j in df[i]:
            if j>Q3+1.5*IQR or j<Q1-1.5*IQR:
                if i not in outliers:
                    outliers[i]=0
                else:
                    outliers[i]+=1
print(outliers)
# Out:
# {'Release date': 1, 'Max resolution': 1, 'Low resolution': 0, 'Effective pixels': 1, 'Zoom wide (W)': 89, 'Zoom tele (T)': 281, 'Normal focus range': 14, 'Macro focus range': 102, 'Storage included': 37, 'Weight (inc. batteries)': 115, 'Dimensions': 49, 'Price': 143}

# %% [markdown]
# There is no need to remove the outliers for our dataset because it is valid numerical values which describe dataset correctly.

# %% [markdown]
# There is no inconsistent data and no incorrect data in the dataset.

# %% [markdown]
# Correlation:

# %% [markdown]
# Correlation of the various variables in the dataset amongst themselves.

# %%
df.corr(method='pearson')
# Out:
#                          Release date  Max resolution  Low resolution  \
# Release date                 1.000000        0.793229        0.788348
# Max resolution               0.793229        1.000000        0.903539
# Low resolution               0.788348        0.903539        1.000000
# Effective pixels             0.727437        0.897375        0.854653
# Zoom wide (W)               -0.158559       -0.257676       -0.207279
# Zoom tele (T)                0.219224        0.207330        0.228487
# Normal focus range          -0.036885       -0.016576        0.003808
# Macro focus range           -0.280573       -0.286491       -0.293249
# Storage included             0.228688        0.238868        0.243829
# Weight (inc. batteries)     -0.277609        0.094312        0.054294
# Dimensions                  -0.368209       -0.088711       -0.117810
# Price                       -0.023249        0.182783        0.133804
#
# ...

# %% [markdown]
# Correlation Graph: Heat map

# %%
df_corr=df.corr(method='pearson')
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(df_corr, annot=True, ax=ax)
plt.title('Correlation for camera attributes')
plt.show()

# %% [markdown]
# Scatter Plot:

# %%
fig= plt.figure(figsize=(15,15))
ax2=fig.add_subplot(331)
plt.scatter(df['Low resolution'], df['Max resolution'])
plt.title('Low ressolution & High Resolution')
plt.xlabel('Low Resolution')
plt.ylabel('Max Resolution')
ax2=fig.add_subplot(332)
plt.scatter(df["Effective pixels"], df['Max resolution'])
plt.title('Effective pixels & Max resolution ')
plt.xlabel('Effective pixels')
plt.ylabel('Max resolution')
ax2=fig.add_subplot(333)
plt.scatter(df['Release date'],df['Effective pixels'])
plt.title('Release date & Effective pixels')
plt.xlabel('Release date')
plt.ylabel('Effective pixels')
plt.show()

# %% [markdown]
# Covariance:
# The measure of how the variables vary with respect to one another

# %%
df.cov()
# Out:
#                          Release date  Max resolution  Low resolution  \
# Release date                 7.424289     1633.146553     1545.303242
# Max resolution            1633.146553   570949.725569   491150.215456
# Low resolution            1545.303242   491150.215456   517531.874048
# Effective pixels             5.380681     1840.717836     1669.062486
# Zoom wide (W)               -1.354360     -610.363161     -467.454111
# Zoom tele (T)               51.437875    13490.526141    14154.644868
# Normal focus range          -1.700580     -211.925195       46.353900
# Macro focus range           -5.780217    -1636.741349    -1595.056176
# Storage included            16.610880     4811.488099     4676.013450
# Weight (inc. batteries)   -193.701384    18249.019204    10002.104040
# Dimensions                 -20.940131    -1399.058778    -1768.925262
# Price                      -48.173224   105028.653377    73199.905112
#
# ...

# %% [markdown]
# Data Preprocessing:

# %% [markdown]
# KMeans Classification which is a clustering Algorithm:

# %%
from sklearn.cluster import KMeans
import sklearn.metrics as sm

# %%
chosen=['Release date','Max resolution','Low resolution','Effective pixels','Zoom wide (W)','Zoom tele (T)','Normal focus range','Macro focus range','Storage included','Weight (inc. batteries)','Dimensions','Price']
X=df[chosen].values
model = KMeans(n_clusters=2)
model.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = StandardScaler().fit_transform(X)
print(x)
# Out:
# [[-2.41993726e+00 -1.92394895e+00 -1.71235827e+00 ...  3.67757303e-01
#   -5.65358748e-01 -3.66253558e-01]
#  [-2.05275485e+00 -1.58498748e+00 -1.71235827e+00 ...  3.67757303e-01
#    2.45453669e+00 -3.66253558e-01]
#  [-1.31839003e+00 -2.43239115e+00 -3.77826576e-04 ... -2.22084248e-16
#   -3.80754166e-02 -3.66253558e-01]
#  ...
#  [-9.51207616e-01 -5.68103081e-01 -1.17832051e+00 ...  5.52015101e-02
#    9.85943170e-03 -5.20183402e-01]
#  [-9.51207616e-01 -1.02031065e-01 -9.33553196e-01 ...  5.52015101e-02
#    9.85943170e-03 -5.20183402e-01]
#  [-5.84025204e-01 -1.16128565e+00 -1.48984254e+00 ... -5.69910075e-01
#   -9.96772382e-01 -4.32035542e-01]]

# %% [markdown]
# PCA Analysis:

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#       principal component 1  principal component 2
# 0                 -4.063260              -0.174233
# 1                 -3.565766               1.610672
# 2                 -2.576437              -0.571807
# 3                 -2.759169              -0.010697
# 4                 -2.878626               0.718695
# ...                     ...                    ...
# 1033              -1.795036               0.290815
# 1034              -1.893865               0.238052
# 1035              -1.785925              -0.206638
# 1036              -1.395752              -0.194060
# 1037              -2.749791              -1.382585
#
# [1038 rows x 2 columns]

# %% [markdown]
# Graphs of PCA Analysis:

# %%
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [6.15080895e-01 3.21996547e-01 3.03836329e-02 2.81671753e-02
#  3.68629908e-03 3.84216107e-04 1.61655928e-04 1.06458800e-04
#  2.63548059e-05 5.13158929e-06 8.89201917e-07 7.45019327e-07]

# %%
plt.scatter(principalDf['principal component 1'],principalDf['principal component 2'],s=30,c='goldenrod',alpha=0.5)
plt.title('plotting both variables')
plt.xlabel('Principal component 1')
plt.ylabel('Principal component 2')
plt.show()

# %% [markdown]
# Data Visualization:

# %% [markdown]
# Histogram:

# %%
df.hist(column=["Release date","Max resolution","Low resolution","Effective pixels","Zoom wide (W)","Zoom tele (T)","Normal focus range","Macro focus range","Storage included","Weight (inc. batteries)","Dimensions","Price"],bins=20,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Release date'}>,
#         <AxesSubplot:title={'center':'Max resolution'}>,
#         <AxesSubplot:title={'center':'Low resolution'}>],
#        [<AxesSubplot:title={'center':'Effective pixels'}>,
#         <AxesSubplot:title={'center':'Zoom wide (W)'}>,
#         <AxesSubplot:title={'center':'Zoom tele (T)'}>],
#        [<AxesSubplot:title={'center':'Normal focus range'}>,
#         <AxesSubplot:title={'center':'Macro focus range'}>,
#         <AxesSubplot:title={'center':'Storage included'}>],
#        [<AxesSubplot:title={'center':'Weight (inc. batteries)'}>,
#         <AxesSubplot:title={'center':'Dimensions'}>,
#         <AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %% [markdown]
# Bar Chart:

# %%
plt.style.use('fivethirtyeight')
print(df.pivot_table(index=['Release date'], aggfunc='size').plot(kind='bar',color=['red','green','orange','yellow','black','violet','indigo','blue','purple','grey','skyblue']))
plt.ylabel=["No. of cameras"]
plt.title("Number of Models produced throughout the year")
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# Text(0.5, 1.0, 'Number of Models produced throughout the year')

# %% [markdown]
# Line Graph: Growth in Production

# %%
growth_rate=[]
growth=list(df["Release date"].value_counts())
dates=set(df["Release date"])
j=0
for i in growth:
    growth_rate.append(int(j-i))
    j=i
del(growth_rate[0])
growth.clear()
for i in growth_rate:
    growth.insert(0,i)
del(growth_rate)
dates=list(dates)
del(dates[0])
plt.figure(figsize=(6,6))
plt.plot(dates,growth)

# %% [markdown]
# Plot representing no.of models manufactured by individual manufacturers:

# %%
Manufacturer=list()
release_dates=set(df["Release date"])
for i in df['Model']:
    if('Agfa' in i):
        Manufacturer.append('Agfa')
    elif('Canon' in i):
        Manufacturer.append('Canon')
    elif('Casio' in i):
        Manufacturer.append('Casio')
    elif('Contax' in i):
        Manufacturer.append('Contax')
    elif('Epson' in i):
        Manufacturer.append('Epson')
    elif('Fujifilm' in i):
        Manufacturer.append('Fujifilm')
    elif('HP' in i):
        Manufacturer.append('HP')
    elif('JVC' in i):
        Manufacturer.append('JVC')
    elif('Kodak' in i):
        Manufacturer.append('Kodak')
    elif('Kyocera' in i):
        Manufacturer.append('Kyocera')
    elif('Leica' in i):
        Manufacturer.append('Leica')
    elif('Nikon' in i):
        Manufacturer.append('Nikon')
    elif('Olympus' in i):
        Manufacturer.append('Olympus')
    elif('Panasonic' in i):
        Manufacturer.append('Panasonic')
    elif('Pentax' in i):
        Manufacturer.append('Pentax')
    elif('Ricoh' in i):
        Manufacturer.append('Ricoh')
    elif('Samsung' in i):
        Manufacturer.append('Samsung')
    elif('Sanyo' in i):
        Manufacturer.append('Sanyo')
    elif('Sigma' in i):
        Manufacturer.append('Sigma')
    elif('Sony' in i):
        Manufacturer.append('Sony')
    elif('Toshiba' in i):
        Manufacturer.append('Toshiba')
df['Manufacturer']=Manufacturer

# %%
df.pivot_table(index=['Manufacturer'], aggfunc='size').plot(kind='barh',color=['red','green','orange','yellow','black','violet','indigo','blue','purple','grey','skyblue'],figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='Manufacturer'>

# %% [markdown]
# Combination of Line and Scatter plot:
# Showing the trend of the features of Dataset

# %%
g_df=df.groupby('Release date')

# %%
df['Range'] = (df['Zoom tele (T)'] - df['Zoom wide (W)']).abs()

# %%
plt.figure(figsize=(8,8))
plt.scatter(x=df['Release date'], y=df['Zoom tele (T)'],c='green')
plt.scatter(x=df['Release date'], y=df['Zoom wide (W)'],c='red',alpha=0.4)
plt.scatter(x=df[df['Range'] >25]['Release date'], y=df[df['Range'] >25]['Range'],c='green')
plt.scatter(x=df[(df['Range'] >100) & (df['Range'] < 200)]['Release date'], y=df[(df['Range'] >100) & (df['Range'] < 200)]['Price'],c='green')
plt.scatter(x=df[(df['Range'] >200) & (df['Range'] < 250)]['Release date'], y=df[(df['Range'] >200) & (df['Range'] < 250)]['Price'],c='Yellow')
plt.scatter(x=df[df['Range'] >250]['Release date'], y=df[df['Range'] >250]['Price'],c='Red', alpha=0.2)
plt.scatter(x=df['Release date'], y=df['Storage included'],c='green',alpha=0.2)
plt.scatter(x=df[(df['Range'] >100) & (df['Range'] < 200)]['Release date'], y=df[(df['Range'] >100) & (df['Range'] < 200)]['Dimensions'],c='green')
plt.scatter(x=df[(df['Range'] >200) & (df['Range'] < 250)]['Release date'], y=df[(df['Range'] >200) & (df['Range'] < 250)]['Dimensions'],c='Yellow')
plt.scatter(x=df[df['Range'] >250]['Release date'], y=df[df['Range'] >250]['Dimensions'],c='Red', alpha=0.2)
plt.scatter(x=df[(df['Range'] >100) & (df['Range'] < 200)]['Release date'], y=df[(df['Range'] >100) & (df['Range'] < 200)]['Weight (inc. batteries)'],c='green')
plt.scatter(x=df[(df['Range'] >200) & (df['Range'] < 250)]['Release date'], y=df[(df['Range'] >200) & (df['Range'] < 250)]['Weight (inc. batteries)'],c='Yellow')
plt.scatter(x=df[df['Range'] >250]['Release date'], y=df[df['Range'] >250]['Weight (inc. batteries)'],c='Red', alpha=0.2)
g_df['Max resolution'].max().plot(color='green',legend=True)
g_df['Low resolution'].max().plot(color='red',legend=True)
g_df['Zoom tele (T)'].max().plot(color='green',legend=True)
g_df['Zoom wide (W)'].min().plot(color='red',legend=True)
#g_df['Range'].max().plot(color='green',legend=True)
g_df['Storage included'].max().plot(color='green',legend=True)
g_df['Dimensions'].min().plot(color='blue',legend=True)
g_df['Dimensions'].max().plot(color='black',legend=True)
g_df['Weight (inc. batteries)'].min().plot(color='blue',legend=True)
g_df['Weight (inc. batteries)'].max().plot(color='black',legend=True)
# Out:
# <AxesSubplot:xlabel='Release date'>

# %% [markdown]
# Data Preprocessing:
# Normalization

# %%
numeric_dataset = df[["Release date","Max resolution","Low resolution","Effective pixels","Zoom wide (W)","Zoom tele (T)","Normal focus range","Macro focus range","Storage included","Weight (inc. batteries)","Dimensions","Price"]]
df=(numeric_dataset-numeric_dataset.mean())/numeric_dataset.std()

# %%
df
# Out:
#       Release date  Max resolution  Low resolution  Effective pixels  \
# 0        -2.418771       -1.923022       -1.711533         -0.269358
# 1        -2.051766       -1.584224       -1.711533         -1.374472
# 2        -1.317755       -2.431219       -0.000378         -0.269358
# 3        -1.684760       -1.753623       -1.711533         -0.269358
# 4        -1.684760       -1.753623       -1.711533         -0.269358
# ...            ...             ...             ...               ...
# 1033     -0.950749       -0.567829       -1.177753         -0.637729
# 1034     -1.317755       -0.567829       -1.177753         -0.637729
# 1035     -0.950749       -0.567829       -1.177753         -0.637729
# 1036     -0.950749       -0.101982       -0.933103         -0.637729
# 1037     -0.583744       -1.160726       -1.489125         -1.374472
#
#       Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# ...

# %% [markdown]
# Team Members:
# Pawan Prasad P
# Phani Kumar Vedurumudi
# Jayanth O
# G U Deepak
